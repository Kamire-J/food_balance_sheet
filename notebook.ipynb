# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# ## Question One

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age', 'Nationality', 'Overall']

# %%
df = pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])

# %%
df.head()
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# ## Question Two

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
print(array[:1])
# Out:
# [[94, 89, 63]]

# %%
data.shape
# Out:
# (60943, 12)

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
print(y[1][-1])
# Out:
# 8

# %%
data.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# ## Question 11

# %%
data.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
data.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %% [markdown]
# ## Question 12

# %%
data.mean().round(3)
# Out:
# /var/folders/hy/b3n1wkjx6j5c7c08qm9ts02m0000gn/T/ipykernel_70232/557497325.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean().round(3)
# Area Code        134.266
# Item Code       2687.177
# Element Code    3814.856
# Y2014            134.196
# Y2015            135.236
# Y2016            136.555
# Y2017            140.918
# Y2018            143.758
# dtype: float64

# %%
data.std().round(3)
# Out:
# /var/folders/hy/b3n1wkjx6j5c7c08qm9ts02m0000gn/T/ipykernel_70232/1654597692.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std().round(3)
# Area Code         72.606
# Item Code        146.056
# Element Code    2212.007
# Y2014           1567.664
# Y2015           1603.404
# Y2016           1640.007
# Y2017           1671.862
# Y2018           1710.783
# dtype: float64

# %%
data.describe().round(3)
# Out:
#        Area Code  Item Code  Element Code       Y2014       Y2015       Y2016  \
# count  60943.000  60943.000     60943.000   59354.000   59395.000   59408.000
# mean     134.266   2687.177      3814.856     134.196     135.236     136.555
# std       72.606    146.056      2212.007    1567.664    1603.404    1640.007
# min        4.000   2501.000       511.000   -1796.000   -3161.000   -3225.000
# 25%       74.000   2562.000       684.000       0.000       0.000       0.000
# 50%      136.000   2630.000      5142.000       0.090       0.080       0.080
# 75%      195.000   2775.000      5511.000       8.340       8.460       8.430
# max      276.000   2961.000      5911.000  176405.000  181137.000  185960.000
#
#             Y2017       Y2018
# count   59437.000   59507.000
# mean      140.918     143.758
# std      1671.862    1710.783
# min     -1582.000   -3396.000
# 25%         0.000       0.000
# 50%         0.100       0.070
# 75%         9.000       9.000
# ...

# %% [markdown]
# ## Question 13

# %%
data['Y2016'].isnull().sum()
# Out:
# 1535

# %%
missing_percentage = data.isnull().sum() * 100/len(data)
missing_values_df = pd.DataFrame({'column_name':data.columns, 'percent_missing': missing_percentage})
missing_values_df
# Out:
#                column_name  percent_missing
# Area Code        Area Code         0.000000
# Area                  Area         0.000000
# Item Code        Item Code         0.000000
# Item                  Item         0.000000
# Element Code  Element Code         0.000000
# Element            Element         0.000000
# Unit                  Unit         0.000000
# Y2014                Y2014         2.607354
# Y2015                Y2015         2.540078
# Y2016                Y2016         2.518747
# Y2017                Y2017         2.471162
# Y2018                Y2018         2.356300

# %% [markdown]
# ## Question 14

# %%
data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# ## Question 15

# %%
data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ## Question 17

# %%
new_df = data.groupby(['Y2018', 'Element']).sum()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     print(new_df)

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
algeria = data.groupby(['Element','Area']).sum()
with pd.option_context('display.max_rows', None):  # more options can be specified also
     print(algeria)
# Out:
#                                                                     Area Code  \
# Element                                Area
# Domestic supply quantity               Algeria                            464
#                                        Angola                             826
#                                        Benin                             6148
#                                        Botswana                          2340
#                                        Burkina Faso                     27494
#                                        Cabo Verde                        4025
#                                        Cameroon                          3808
#                                        Central African Republic          4292
#                                        Chad                              4641
#                                        Comoros                            405
# ...

# %%
list1 = data['Area'].unique()

# %%
len(list1)
# Out:
# 49
